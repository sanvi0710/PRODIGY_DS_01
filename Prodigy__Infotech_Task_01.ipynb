# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94746b4a-ca8e-4204-93a9-f19f8a545233" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94746b4a-ca8e-4204-93a9-f19f8a545233">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("world_population_data.csv.csv", skiprows=4)

# %%
df.shape
# Out:
# (266, 70)

# %%
df.head(5)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
df.tail(5)
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    984846.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261   1011421.0   1036950.0   1062737.0   1090270.0   1120168.0  ...
# 262   5655232.0   5782221.0   5911135.0   6048006.0   6195593.0  ...
# 263  16908035.0  17418522.0  17954564.0  18511361.0  19089380.0  ...
# 264   3254086.0   3358099.0   3465907.0   3577017.0   3692086.0  ...
# 265   3930401.0   4055959.0   4185877.0   4320006.0   4458462.0  ...
#
#            2017        2018        2019        2020        2021        2022  \
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154480e+08  1.170538e+08  1.192160e+08  1.218878e+08  1.245835e+08
# std    3.626523e+08  3.671660e+08  3.738303e+08  3.824608e+08  3.911397e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021529e+09  3.062769e+09  3.117373e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.273111e+08  1.301581e+08  1.330127e+08  1.359425e+08  1.389705e+08
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2021                1
# 2022                1
# 2023                1
# 2024              266
# Unnamed: 69       266
# Length: 70, dtype: int64

# %%
print(df['Country Name'].unique())
# Out:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
# ...

# %%
print(df['Country Code'].unique())
# Out:
# ['ABW' 'AFE' 'AFG' 'AFW' 'AGO' 'ALB' 'AND' 'ARB' 'ARE' 'ARG' 'ARM' 'ASM'
#  'ATG' 'AUS' 'AUT' 'AZE' 'BDI' 'BEL' 'BEN' 'BFA' 'BGD' 'BGR' 'BHR' 'BHS'
#  'BIH' 'BLR' 'BLZ' 'BMU' 'BOL' 'BRA' 'BRB' 'BRN' 'BTN' 'BWA' 'CAF' 'CAN'
#  'CEB' 'CHE' 'CHI' 'CHL' 'CHN' 'CIV' 'CMR' 'COD' 'COG' 'COL' 'COM' 'CPV'
#  'CRI' 'CSS' 'CUB' 'CUW' 'CYM' 'CYP' 'CZE' 'DEU' 'DJI' 'DMA' 'DNK' 'DOM'
#  'DZA' 'EAP' 'EAR' 'EAS' 'ECA' 'ECS' 'ECU' 'EGY' 'EMU' 'ERI' 'ESP' 'EST'
#  'ETH' 'EUU' 'FCS' 'FIN' 'FJI' 'FRA' 'FRO' 'FSM' 'GAB' 'GBR' 'GEO' 'GHA'
#  'GIB' 'GIN' 'GMB' 'GNB' 'GNQ' 'GRC' 'GRD' 'GRL' 'GTM' 'GUM' 'GUY' 'HIC'
#  'HKG' 'HND' 'HPC' 'HRV' 'HTI' 'HUN' 'IBD' 'IBT' 'IDA' 'IDB' 'IDN' 'IDX'
#  'IMN' 'IND' 'INX' 'IRL' 'IRN' 'IRQ' 'ISL' 'ISR' 'ITA' 'JAM' 'JOR' 'JPN'
#  'KAZ' 'KEN' 'KGZ' 'KHM' 'KIR' 'KNA' 'KOR' 'KWT' 'LAC' 'LAO' 'LBN' 'LBR'
#  'LBY' 'LCA' 'LCN' 'LDC' 'LIC' 'LIE' 'LKA' 'LMC' 'LMY' 'LSO' 'LTE' 'LTU'
#  'LUX' 'LVA' 'MAC' 'MAF' 'MAR' 'MCO' 'MDA' 'MDG' 'MDV' 'MEA' 'MEX' 'MHL'
# ...

# %%
# Filter out aggregate country groups
countries_to_exclude = [
    "Low & middle income","Middle income","IBRD only","Early-demographic dividend","Upper middle income", "High income", "Low income",
    "Lower middle income", "Late-demographic dividend", "Post-demographic dividend", "IDA & IBRD total", "IDA total", "IDA blend",
    "IDA only", "Euro area", "East Asia & Pacific (excluding high income)","East Asia & Pacific","Europe & Central Asia (excluding high income)",
    "Europe & Central Asia","Latin America & Caribbean (excluding high income)","Latin America & Caribbean","Middle East & North Africa",
    "Middle East & North Africa (excluding high income)","North America","South Asia","Sub-Saharan Africa (excluding high income)","Sub-Saharan Africa",
    "World","Arab World", "Central Europe and the Baltics","Caribbean small states","Central African Republic", "Channel Islands",
    "Developing small island states","East Asia & Pacific (IDA & IBRD countries)","Europe & Central Asia (IDA & IBRD countries)",
    "Fragile and conflict affected situations","Heavily indebted poor countries (HIPC)","High income: nonOECD","High income: OECD",
    "Latin America & the Caribbean (IDA & IBRD countries)","Least developed countries: UN classification","Middle East & North Africa (IDA & IBRD countries)",
    "Pacific island small states","Small states","South Asia (IDA & IBRD)","Sub-Saharan Africa (IDA & IBRD countries)",
    "Other small states","Pre-demographic dividend","European Union","Least Developed Countries","Less Developed Regions",
    "More Developed Regions","Land Locked Developing Countries","Small Island Developing States","Eastern and South-Eastern Asia",
    "Northern Africa and Western Asia","Oceania","Northern America and Europe","Eastern and Southern Africa","Middle Africa",
    "Western Africa","Western Asia","OECD members","Not classified"
]
# Apply the filter to the DataFrame
df = df[~df["Country Name"].isin(countries_to_exclude)]

# %%
df['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana', 'Canada', 'Switzerland',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Cuba', 'Curacao', 'Cayman Islands', 'Cyprus', 'Czechia',
#        'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic',
#        'Algeria', 'Ecuador', 'Egypt, Arab Rep.', 'Eritrea', 'Spain',
# ...

# %%
year_cols = [col for col in df.columns if col.isdigit()]
df['Total Population'] = df[year_cols].sum(axis=1, skipna = True)

# %%
df.head(3)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
#
#           1965  ...         2017         2018         2019         2020  \
# 0      58190.0  ...     108735.0     108908.0     109203.0     108587.0
# 1  149033472.0  ...  640058741.0  657801085.0  675950189.0  694446100.0
# 2   10036008.0  ...   35688935.0   36743039.0   37856121.0   39068979.0
#
#           2021         2022         2023  2024  Unnamed: 69  Total Population
# ...

# %%
#find the top 10 countries by total population
top_10_countries = df.sort_values(by='Total Population', ascending=False).head(10)
colors = sns.color_palette('pastel')
plt.figure(figsize=(10, 6))
plt.bar(top_10_countries['Country Name'], top_10_countries['Total Population'], color=colors)
plt.xlabel('Country')
plt.ylabel('Total Population')
plt.title('Top 10 Countries with the Highest Total Population')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#find the top 10 countries in 2018
population_df = df[df['Indicator Name'] == 'Population, total']
year = '2018'
data_2020 = population_df[['Country Name', year]].dropna()


data_2020_sorted = data_2020.sort_values(by=year, ascending=False)
colors = sns.color_palette('pastel')
plt.figure(figsize=(10, 6))
plt.bar(top_10_countries['Country Name'], top_10_countries[year].astype(int), color=colors)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title(f'Top 10 Countries by population in {year}')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#find the bottom 10 countries by total population
bottom_10_countries = df.sort_values(by='Total Population', ascending=True).head(10)

colors = sns.color_palette('pastel', n_colors=10)

plt.figure(figsize=(10, 6))
plt.bar(bottom_10_countries['Country Name'], bottom_10_countries['Total Population'], color=colors)
plt.xlabel('Country')
plt.ylabel('Total Population')
plt.title('Bottom 10 Countries with the Lowest Total Population')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#for 2016 top 10 countries
top_10_2016 = df.sort_values(by='2016', ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(
    data=top_10_2016,
    x='Country Name',
    y='2016',
    hue='Country Name',
    palette='Blues_d',
    legend=False
)
plt.title('Population in 2016 - Top 10 Countries')
plt.xlabel('Country')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- Top 10 Countries by 2023 Population ---
top_10_2023 = df.sort_values(by='2023', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=top_10_2023,
    x='Country Name',
    y='2023',
    hue='Country Name',
    palette='Purples_d',
    legend=False
)
plt.title('Population in 2023 - Top 10 Countries')
plt.xlabel('Country')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 3 countries in 2000, 2010, 2020
selected_years = ["2000", "2010", "2020"]
data = df[df["Country Name"].isin(["India", "China", "United States"])]

data_plot = data.set_index("Country Name")[selected_years].T
data_plot.plot(kind="bar", figsize=(10, 5))
plt.title("Population Comparison (2000, 2010, 2020)")
plt.xlabel("Year"); plt.ylabel("Population")
plt.tight_layout(); plt.show()

# %%
# India population trend
india = df[df["Country Name"] == "India"]
plt.figure(figsize=(8, 4))

# Filter year_cols to include only years from 2010 to 2023
recent_year_cols = [col for col in year_cols if int(col) >= 2010]

# Use recent_year_cols for plotting
plt.plot(recent_year_cols, india[recent_year_cols].values.flatten(), label="India", color='blue')
plt.title("India Population Growth (2010–2023)")
plt.xlabel("Year"); plt.ylabel("Population"); plt.grid(True)
plt.tight_layout(); plt.show()

# %%
# India, China comparison
countries = df[df["Country Name"].isin(["India", "China"])]
plt.figure(figsize=(10, 5))
for _, row in countries.iterrows():
    plt.plot(year_cols, row[year_cols], label=row["Country Name"])

plt.legend(); plt.title("Population Growth: India, China")
plt.xlabel("Year"); plt.ylabel("Population"); plt.grid(False)
plt.xticks(rotation='vertical')
plt.tight_layout(); plt.show()

# %%
# Bar Chart: Top 10 most populous countries

# Filter the DataFrame to include only the 'Country Name' and '2022' columns
df_2022 = df[['Country Name', '2022']].copy()

# Rename the columns for clarity in the plot
df_2022.rename(columns={'Country Name': 'Country', '2022': '2022'}, inplace=True)

# Drop any rows with missing values in the '2022' column
df_2022.dropna(subset=['2022'], inplace=True)

# Sort the DataFrame by the '2022' population and get the top 10
top10 = df_2022.sort_values(by="2022", ascending=False).head(10)

plt.figure(figsize=(12,6))
sns.barplot(x="2022", y="Country", data=top10, palette="viridis")
plt.title("Top 10 Most Populous Countries (2022)", fontsize=14)
plt.xlabel("Population", fontsize=12)
plt.ylabel("Country", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-41-d0aa204cb586>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2022", y="Country", data=top10, palette="viridis")

# %%
#  Histogram: Distribution of populations
plt.figure(figsize=(10,6))
sns.histplot(df_2022["2022"], bins=30, kde=True, color="skyblue")
plt.title("Distribution of Country Populations in 2022", fontsize=14)
plt.xlabel("Population", fontsize=12)
plt.ylabel("Number of Countries", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
most_populous = df_2022.sort_values(by="2022", ascending=False).iloc[0]
print(f"The most populous country in 2022 was {most_populous['Country']} with a population of {most_populous['2022']:.0f}.")
# Out:
# The most populous country in 2022 was India with a population of 1425423212.
